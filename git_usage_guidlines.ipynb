# %% [markdown]
# # Github Usage Guidlines

# %%
#### Open terminal/command box in your system

# %% [markdown]
# Step 1 . Navigate to the working directory of the folder where your scripts are placed

# %%
#Initialize the git repository at that location

# %% [markdown]
# Step 2. git init

# %%
#Configure your github account by passing username

# %% [markdown]
# Step 3. git config --global user.name 'your username'

# %%
#Configure your github account by passing email id

# %% [markdown]
# Step 4. git config --global user.email 'your email_id'

# %%
#Add the relevant file to github staging area

# %% [markdown]
# Step 5. git add filname

# %%
# Verify the file status ( files modified/pending to be added /already added)

# %% [markdown]
# Step 6. git status

# %%
# Commit the changes in the file to Github

# %% [markdown]
# Step 7. git commit -m 'comments regarding file /changes made/version info'

# %% [markdown]
# ## Next steps at github website

# %% [markdown]
# Step 8. Login to your github account

# %% [markdown]
# Step 9. Create a new project /repository

# %%
#Avoid selecting readme file for initial part

# %%
from IPython.display import Image
Image(filename='git.png')

# %% [markdown]
# ### Come back to terminal/command box at local system

# %% [markdown]
# Step 10. git remote add origin http://github.com/username/project.git

# %% [markdown]
# Step 11. git push -u origin master

# %% [markdown]
# ## Branching

# %% [markdown]
# ##### In case branching is required

# %% [markdown]
# Step 1. git branch branchname

# %% [markdown]
# Step 2. git checkout branchname

# %% [markdown]
# Step 3. git commit -m 'comments'

# %% [markdown]
# Step 4. git push -u origin branchname
