# %% [markdown]
# # Introduction to Pandas

# %% [markdown]
# ##### Pandas is an open source Python library for data analysis. It gives Python the ability to work with spreadsheet-like data for fast data loading, manipulating, aligning, and merging

# %% [markdown]
# ### There are two main components of Pandas
# ### Series and DataFrame
# The DataFrame represents your entire spreadsheet or rectangular data, whereas the Series is a single column of the DataFrame.

# %%
#import numpy, pandas and matplotlib libraies
import numpy as np
import pandas as pd
from pandas import *
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Series

# %%
#create a series 
ser=pd.Series([1,2,3,4,5])
ser
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
#access the series element values
ser.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
#access the series indexes
ser.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
#series with custom index
sample_ser=pd.Series([32,88,76,75,19],index=['a','b','c','d','e'])
sample_ser
# Out:
# a    32
# b    88
# c    76
# d    75
# e    19
# dtype: int64

# %%
#indexing of series
sample_ser['c']
# Out:
# 76

# %%
#assigning values to series via indexes
sample_ser['d']=100

# %%
sample_ser
# Out:
# a     32
# b     88
# c     76
# d    100
# e     19
# dtype: int64

# %%
#create a series with custom index passed as a list
states = ['California', 'Ohio', 'Oregon', 'Texas']
data=[100,200,300,400]
state_ser= pd.Series(data, index=states)

# %%
state_ser
# Out:
# California    100
# Ohio          200
# Oregon        300
# Texas         400
# dtype: int64

# %% [markdown]
# ## Filtering Condtions

# %%
#fetch records based on condition
sample_ser[sample_ser >75]
# Out:
# b     88
# c     76
# d    100
# dtype: int64

# %%
#validate if particular index in series
'e' in sample_ser
# Out:
# True

# %%
#converting series into dictionary
ser_dict=sample_ser.to_dict()
ser_dict
# Out:
# {'a': 32, 'b': 88, 'c': 76, 'd': 100, 'e': 19}

# %%
#converting dictionary to series
dict_ser=pd.Series(ser_dict)
dict_ser
# Out:
# a     32
# b     88
# c     76
# d    100
# e     19
# dtype: int64

# %% [markdown]
# ## Dataframes

# %% [markdown]
# #### Three ways you can create Dataframe Objects in Python
#
# 1. Reading data from webpage
# 2. Reading data from a file location ( local/cloud/database)
# 3. Creating a dataframe locally by passing values using pandas DataFrame function

# %% [markdown]
# #### Case I : Reading from a webpage

# %% [markdown]
# #### Case II : Reading Data from a file lcoation

# %%
#create a pandas dataframe using read_csv function 
df=pd.read_csv('nfl.csv')

# %%
#generic information about df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 10 columns):
# Rank                32 non-null int64
# Team                32 non-null int64
# Won                 32 non-null object
# Lost                32 non-null int64
# Tied                32 non-null int64
# Pct.                32 non-null int64
# First NFL Season    32 non-null float64
# Total Games         32 non-null int64
# Division            32 non-null object
# Zone                32 non-null object
# dtypes: float64(1), int64(6), object(3)
# memory usage: 2.6+ KB

# %%
#Generate statistics values of df
df.describe()
# Out:
#             Rank       Team        Lost        Tied       Pct.  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000
# mean   15.500000  16.500000  448.437500  439.593750  13.250000
# std     9.380832   9.380832  156.415893  137.048816  12.492578
# min     0.000000   1.000000  110.000000  146.000000   0.000000
# 25%     7.750000   8.750000  351.000000  389.000000   4.750000
# 50%    15.500000  16.500000  462.000000  440.500000   9.500000
# 75%    23.250000  24.250000  550.750000  543.250000  20.250000
# max    31.000000  32.000000  749.000000  740.000000  42.000000
#
#        First NFL Season  Total Games
# count         32.000000    32.000000
# mean           0.500531  1956.625000
# std            0.047509    22.511287
# min            0.387000  1920.000000
# 25%            0.460000  1936.000000
# 50%            0.502500  1960.000000
# 75%            0.537500  1966.250000
# max            0.573000  2002.000000

# %%
# Columns present in dataframe
df.columns
# Out:
# Index(['Rank', 'Team', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL Season',
#        'Total Games', 'Division', 'Zone'],
#       dtype='object')

# %%
#Wrong way of accessing columns  with space in names
df.Total Games
# Out:
#   File "<ipython-input-52-103eb8238ae1>", line 2
#     df.Total Games
#                  ^
# SyntaxError: invalid syntax

# %%
#correct way of accessing column values for such columns
df['Total Games']
# Out:
# 0     1960
# 1     1921
# 2     1920
# 3     1966
# 4     1960
# 5     1961
# 6     1996
# 7     1925
# 8     1960
# 9     1950
# 10    1933
# 11    1960
# 12    1953
# 13    1960
# 14    1976
# 15    1932
# 16    1995
# 17    1960
# 18    1937
# 19    1950
# 20    1933
# 21    1960
# 22    1960
# 23    1930
# 24    1968
# 25    1960
# 26    1995
# 27    1967
# 28    1966
# 29    2002
# 30    1920
# 31    1976
# Name: Total Games, dtype: int64

# %%
#sneak peek into the datframe , view only top few rows
df.head(3)
# Out:
#    Rank  Team                Won  Lost  Tied  Pct.  First NFL Season  \
# 0     0     1     Dallas Cowboys   502   374     6             0.573
# 1     1     2  Green Bay Packers   737   562    37             0.565
# 2     2     3      Chicago Bears   749   579    42             0.562
#
#    Total Games Division       Zone
# 0         1960      882   NFC East
# 1         1921    1,336  NFC North
# 2         1920    1,370  NFC North

# %%
#last few records of the dataframe
df.tail(2)
# Out:
#     Rank  Team                   Won  Lost  Tied  Pct.  First NFL Season  \
# 30    30    31     Arizona Cardinals   550   740    40             0.429
# 31    31    32  Tampa Bay Buccaneers   255   404     1             0.387
#
#     Total Games Division       Zone
# 30         1920    1,330   NFC West
# 31         1976      660  NFC South

# %%
#random sample view of records 
df.sample(3)
# Out:
#     Rank  Team                      Won  Lost  Tied  Pct.  First NFL Season  \
# 4      4     5  New England Patriots[b]   489   386     9             0.558
# 24    24    25       Cincinnati Bengals   351   417     4             0.457
# 18    18    19         Los Angeles Rams   555   559    21             0.498
#
#     Total Games Division       Zone
# 4          1960      884   AFC East
# 24         1968      772  AFC North
# 18         1937    1,135   NFC West

# %%
#select few columns 
df_small=df[['Rank', 'Team', 'Won', 'Lost','Division','Zone']]

# %%
df_small
# Out:
#     Rank  Team                      Won  Lost Division       Zone
# 0      0     1           Dallas Cowboys   502      882   NFC East
# 1      1     2        Green Bay Packers   737    1,336  NFC North
# 2      2     3            Chicago Bears   749    1,370  NFC North
# 3      3     4           Miami Dolphins   445      800   AFC East
# 4      4     5  New England Patriots[b]   489      884   AFC East
# 5      5     6        Minnesota Vikings   470      870  NFC North
# 6      6     7         Baltimore Ravens   190      352  AFC North
# 7      7     8          New York Giants   687    1,305   NFC East
# 8      8     9           Denver Broncos   470      884   AFC West
# 9      9    10      San Francisco 49ers   528    1,002   NFC West
# 10    10    11      Pittsburgh Steelers   614    1,172  AFC North
# 11    11    12          Oakland Raiders   462      884   AFC West
# 12    12    13    Indianapolis Colts[c]   506      966  AFC South
# 13    13    14       Kansas City Chiefs   457      884   AFC West
# 14    14    15         Seattle Seahawks   334      660   NFC West
# 15    15    16      Washington Redskins   595    1,202   NFC East
# 16    16    17        Carolina Panthers   183      368  NFC South
# 17    17    18     Los Angeles Chargers   435      884   AFC West
# 18    18    19         Los Angeles Rams   555    1,135   NFC West
# 19    19    20         Cleveland Browns   462      954  AFC North
# 20    20    21      Philadelphia Eagles   568    1,188   NFC East
# 21    21    22         Tennessee Titans   422      884  AFC South
# 22    22    23            Buffalo Bills   409      884   AFC East
# 23    23    24            Detroit Lions   553    1,233  NFC North
# 24    24    25       Cincinnati Bengals   351      772  AFC North
# 25    25    26            New York Jets   397      884   AFC East
# 26    26    27     Jacksonville Jaguars   165      368  AFC South
# 27    27    28       New Orleans Saints   349      786  NFC South
# 28    28    29          Atlanta Falcons   351      790  NFC South
# 29    29    30           Houston Texans   110      256  AFC South
# 30    30    31        Arizona Cardinals   550    1,330   NFC West
# 31    31    32     Tampa Bay Buccaneers   255      660  NFC South

# %%
#shape & Size of data
df_small.shape
# Out:
# (32, 6)

# %%
#group by column values
df_small.Zone.value_counts()
# Out:
# NFC West     4
# AFC South    4
# AFC West     4
# AFC East     4
# NFC North    4
# NFC East     4
# NFC South    4
# AFC North    4
# Name: Zone, dtype: int64

# %%
#fetch particular row (first row)
df_small.iloc[0]
# Out:
# Rank                     0
# Team                     1
# Won         Dallas Cowboys
# Lost                   502
# Division               882
# Zone              NFC East
# Name: 0, dtype: object

# %%
#add new column with fixed value
df_small['new_col']=5
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_small
# Out:
#     Rank  Team                      Won  Lost Division       Zone  new_col
# 0      0     1           Dallas Cowboys   502      882   NFC East        5
# 1      1     2        Green Bay Packers   737    1,336  NFC North        5
# 2      2     3            Chicago Bears   749    1,370  NFC North        5
# 3      3     4           Miami Dolphins   445      800   AFC East        5
# 4      4     5  New England Patriots[b]   489      884   AFC East        5
# 5      5     6        Minnesota Vikings   470      870  NFC North        5
# 6      6     7         Baltimore Ravens   190      352  AFC North        5
# 7      7     8          New York Giants   687    1,305   NFC East        5
# 8      8     9           Denver Broncos   470      884   AFC West        5
# 9      9    10      San Francisco 49ers   528    1,002   NFC West        5
# 10    10    11      Pittsburgh Steelers   614    1,172  AFC North        5
# 11    11    12          Oakland Raiders   462      884   AFC West        5
# 12    12    13    Indianapolis Colts[c]   506      966  AFC South        5
# 13    13    14       Kansas City Chiefs   457      884   AFC West        5
# 14    14    15         Seattle Seahawks   334      660   NFC West        5
# 15    15    16      Washington Redskins   595    1,202   NFC East        5
# 16    16    17        Carolina Panthers   183      368  NFC South        5
# 17    17    18     Los Angeles Chargers   435      884   AFC West        5
# 18    18    19         Los Angeles Rams   555    1,135   NFC West        5
# 19    19    20         Cleveland Browns   462      954  AFC North        5
# 20    20    21      Philadelphia Eagles   568    1,188   NFC East        5
# 21    21    22         Tennessee Titans   422      884  AFC South        5
# 22    22    23            Buffalo Bills   409      884   AFC East        5
# 23    23    24            Detroit Lions   553    1,233  NFC North        5
# 24    24    25       Cincinnati Bengals   351      772  AFC North        5
# 25    25    26            New York Jets   397      884   AFC East        5
# 26    26    27     Jacksonville Jaguars   165      368  AFC South        5
# 27    27    28       New Orleans Saints   349      786  NFC South        5
# 28    28    29          Atlanta Falcons   351      790  NFC South        5
# 29    29    30           Houston Texans   110      256  AFC South        5
# 30    30    31        Arizona Cardinals   550    1,330   NFC West        5
# 31    31    32     Tampa Bay Buccaneers   255      660  NFC South        5

# %%
#Add new column with random values
df_small['new_col']=np.arange(32)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_small
# Out:
#     Rank  Team                      Won  Lost Division       Zone  new_col
# 0      0     1           Dallas Cowboys   502      882   NFC East        0
# 1      1     2        Green Bay Packers   737    1,336  NFC North        1
# 2      2     3            Chicago Bears   749    1,370  NFC North        2
# 3      3     4           Miami Dolphins   445      800   AFC East        3
# 4      4     5  New England Patriots[b]   489      884   AFC East        4
# 5      5     6        Minnesota Vikings   470      870  NFC North        5
# 6      6     7         Baltimore Ravens   190      352  AFC North        6
# 7      7     8          New York Giants   687    1,305   NFC East        7
# 8      8     9           Denver Broncos   470      884   AFC West        8
# 9      9    10      San Francisco 49ers   528    1,002   NFC West        9
# 10    10    11      Pittsburgh Steelers   614    1,172  AFC North       10
# 11    11    12          Oakland Raiders   462      884   AFC West       11
# 12    12    13    Indianapolis Colts[c]   506      966  AFC South       12
# 13    13    14       Kansas City Chiefs   457      884   AFC West       13
# 14    14    15         Seattle Seahawks   334      660   NFC West       14
# 15    15    16      Washington Redskins   595    1,202   NFC East       15
# 16    16    17        Carolina Panthers   183      368  NFC South       16
# 17    17    18     Los Angeles Chargers   435      884   AFC West       17
# 18    18    19         Los Angeles Rams   555    1,135   NFC West       18
# 19    19    20         Cleveland Browns   462      954  AFC North       19
# 20    20    21      Philadelphia Eagles   568    1,188   NFC East       20
# 21    21    22         Tennessee Titans   422      884  AFC South       21
# 22    22    23            Buffalo Bills   409      884   AFC East       22
# 23    23    24            Detroit Lions   553    1,233  NFC North       23
# 24    24    25       Cincinnati Bengals   351      772  AFC North       24
# 25    25    26            New York Jets   397      884   AFC East       25
# 26    26    27     Jacksonville Jaguars   165      368  AFC South       26
# 27    27    28       New Orleans Saints   349      786  NFC South       27
# 28    28    29          Atlanta Falcons   351      790  NFC South       28
# 29    29    30           Houston Texans   110      256  AFC South       29
# 30    30    31        Arizona Cardinals   550    1,330   NFC West       30
# 31    31    32     Tampa Bay Buccaneers   255      660  NFC South       31

# %%
#del the column
del df_small['new_col']

# %%
df_small
# Out:
#     Rank  Team                      Won  Lost Division       Zone
# 0      0     1           Dallas Cowboys   502      882   NFC East
# 1      1     2        Green Bay Packers   737    1,336  NFC North
# 2      2     3            Chicago Bears   749    1,370  NFC North
# 3      3     4           Miami Dolphins   445      800   AFC East
# 4      4     5  New England Patriots[b]   489      884   AFC East
# 5      5     6        Minnesota Vikings   470      870  NFC North
# 6      6     7         Baltimore Ravens   190      352  AFC North
# 7      7     8          New York Giants   687    1,305   NFC East
# 8      8     9           Denver Broncos   470      884   AFC West
# 9      9    10      San Francisco 49ers   528    1,002   NFC West
# 10    10    11      Pittsburgh Steelers   614    1,172  AFC North
# 11    11    12          Oakland Raiders   462      884   AFC West
# 12    12    13    Indianapolis Colts[c]   506      966  AFC South
# 13    13    14       Kansas City Chiefs   457      884   AFC West
# 14    14    15         Seattle Seahawks   334      660   NFC West
# 15    15    16      Washington Redskins   595    1,202   NFC East
# 16    16    17        Carolina Panthers   183      368  NFC South
# 17    17    18     Los Angeles Chargers   435      884   AFC West
# 18    18    19         Los Angeles Rams   555    1,135   NFC West
# 19    19    20         Cleveland Browns   462      954  AFC North
# 20    20    21      Philadelphia Eagles   568    1,188   NFC East
# 21    21    22         Tennessee Titans   422      884  AFC South
# 22    22    23            Buffalo Bills   409      884   AFC East
# 23    23    24            Detroit Lions   553    1,233  NFC North
# 24    24    25       Cincinnati Bengals   351      772  AFC North
# 25    25    26            New York Jets   397      884   AFC East
# 26    26    27     Jacksonville Jaguars   165      368  AFC South
# 27    27    28       New Orleans Saints   349      786  NFC South
# 28    28    29          Atlanta Falcons   351      790  NFC South
# 29    29    30           Houston Texans   110      256  AFC South
# 30    30    31        Arizona Cardinals   550    1,330   NFC West
# 31    31    32     Tampa Bay Buccaneers   255      660  NFC South

# %%
#Rename columns
df_small = df_small.rename(columns={'Rank': 'Standings', 'Division': 'Section'})

# %%
df_small
# Out:
#     Standings  Team                      Won  Lost Section       Zone
# 0           0     1           Dallas Cowboys   502     882   NFC East
# 1           1     2        Green Bay Packers   737   1,336  NFC North
# 2           2     3            Chicago Bears   749   1,370  NFC North
# 3           3     4           Miami Dolphins   445     800   AFC East
# 4           4     5  New England Patriots[b]   489     884   AFC East
# 5           5     6        Minnesota Vikings   470     870  NFC North
# 6           6     7         Baltimore Ravens   190     352  AFC North
# 7           7     8          New York Giants   687   1,305   NFC East
# 8           8     9           Denver Broncos   470     884   AFC West
# 9           9    10      San Francisco 49ers   528   1,002   NFC West
# 10         10    11      Pittsburgh Steelers   614   1,172  AFC North
# 11         11    12          Oakland Raiders   462     884   AFC West
# 12         12    13    Indianapolis Colts[c]   506     966  AFC South
# 13         13    14       Kansas City Chiefs   457     884   AFC West
# 14         14    15         Seattle Seahawks   334     660   NFC West
# 15         15    16      Washington Redskins   595   1,202   NFC East
# 16         16    17        Carolina Panthers   183     368  NFC South
# 17         17    18     Los Angeles Chargers   435     884   AFC West
# 18         18    19         Los Angeles Rams   555   1,135   NFC West
# 19         19    20         Cleveland Browns   462     954  AFC North
# 20         20    21      Philadelphia Eagles   568   1,188   NFC East
# 21         21    22         Tennessee Titans   422     884  AFC South
# 22         22    23            Buffalo Bills   409     884   AFC East
# 23         23    24            Detroit Lions   553   1,233  NFC North
# 24         24    25       Cincinnati Bengals   351     772  AFC North
# 25         25    26            New York Jets   397     884   AFC East
# 26         26    27     Jacksonville Jaguars   165     368  AFC South
# 27         27    28       New Orleans Saints   349     786  NFC South
# 28         28    29          Atlanta Falcons   351     790  NFC South
# 29         29    30           Houston Texans   110     256  AFC South
# 30         30    31        Arizona Cardinals   550   1,330   NFC West
# 31         31    32     Tampa Bay Buccaneers   255     660  NFC South

# %% [markdown]
# #### Case III : Create the dataframe locally by passing dictionary values

# %%
#create dictionary for dataframe
player_dict={'Player':['Federer','Murray','Nadal','Djokovic','Sharapova','Williams'],
       200,225 'Matches':[,300,150,275,325],
     'Rank':[1,2,3,4,5,6]}

# %%
#create the dataframe using dictionary values
player_df=pd.DataFrame(player_dict,index=np.arange(1,7))
player_df
# Out:
#    Matches     Player  Rank
# 1      200    Federer     1
# 2      225     Murray     2
# 3      300      Nadal     3
# 4      150   Djokovic     4
# 5      275  Sharapova     5
# 6      325   Williams     6

# %% [markdown]
# # Indexing objects

# %%
#fetch the 4th index for Matches column
player_df.Matches[4]
# Out:
# 150

# %%
player_df.Player[4]
# Out:
# 'Djokovic'

# %%
# Reindexing
player_df.reindex(np.arange(1,8))
# Out:
#    Matches     Player  Rank
# 1    200.0    Federer   1.0
# 2    225.0     Murray   2.0
# 3    300.0      Nadal   3.0
# 4    150.0   Djokovic   4.0
# 5    275.0  Sharapova   5.0
# 6    325.0   Williams   6.0
# 7      NaN        NaN   NaN

# %% [markdown]
# ## Drop rows & columns

# %%
#drop column ( axis=1)
player_df.drop('Rank',axis=1)
# Out:
#    Matches     Player
# 1      200    Federer
# 2      225     Murray
# 3      300      Nadal
# 4      150   Djokovic
# 5      275  Sharapova
# 6      325   Williams

# %%
#drop row ( axis=0)
player_df.drop(6,axis=0)
# Out:
#    Matches     Player  Rank
# 1      200    Federer     1
# 2      225     Murray     2
# 3      300      Nadal     3
# 4      150   Djokovic     4
# 5      275  Sharapova     5

# %% [markdown]
# ## Conditions

# %%
player_df[player_df.Rank < 4]
# Out:
#    Matches   Player  Rank
# 1      200  Federer     1
# 2      225   Murray     2
# 3      300    Nadal     3

# %%
player_df.Rank < 4
# Out:
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# Name: Rank, dtype: bool
